# %%
#!jt -t monokai -T -N -kl
#!jt -r

# %%
import pandas as pd
import matplotlib.pyplot as plt
import datetime as dt
import numpy as np

# %%
# %matplotlib inline
pd.set_option('display.max_rows', 200)
pd.set_option('display.max_columns', 12)
#plt.style.use('dark_background')
plt.style.use('ggplot')

# %%
url_country = 'https://github.com/datasets/covid-19/raw/master/data/countries-aggregated.csv'
country_df = pd.read_csv(url_country)[['Date', 'Country', 'Deaths']]

# %%
W = pd.DataFrame(country_df.groupby('Date').sum())
W['Country'] = ['World' for _ in range(len(W))]
W['Date'] = W.index
country_df = country_df.append(W)
# Out:
# c:\users\prasu\appdata\local\programs\python\python37\lib\site-packages\pandas\core\frame.py:7138: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   sort=sort,

# %%
Deaths = pd.DataFrame()
Deaths['Date'] = country_df.Date.unique()
Deaths['Date'] = pd.to_datetime(Deaths.Date)
#Deaths = Deaths.set_index('Date')

# %%
countries = country_df['Country'].unique()
for c in countries:
    cun = country_df[country_df.Country == c].Deaths
    Deaths[c] = list(cun)
Deaths = Deaths.set_index('Date')

# %%
Important_countries = ['India', 'World', #'World without China',
                      'US', 'Germany', 'Italy', 'Spain', 'China',
                      'United Kingdom', 'France',
                      'Korea, South', 'Iran']#[::-1]
colors = {'India': 'Blue', 'World': 'Blue', 'World without US': 'Green', 'US': 'Black', 'China': 'red', 'Spain': 'yellow',
         'Italy': 'grey', 'Iran': 'brown', 'Ireland': 'violet', 'United Kingdom': 'Purple', 'Korea, South': 'Black',
         'France': 'orange', 'Germany': 'Green'}
def plotter(DF, name, log = True):
    plt.figure(figsize = (14, 7))
    if log:
        plt.yscale('log')
    if len(DF.columns)>len(Important_countries):
        columns = Important_countries
    else:
        columns = DF.columns
    for col in columns:
        plt.plot(DF.index,
                 DF[col],
                 label = col,
                 linestyle = '-.' if 'World' in col else '-',
                 color = colors[col] if col in colors else 'pink', 
                 #alpha = 0.6
                )
    plt.title(name+' wrt Date in Countries')
    plt.xlabel('Date')
    plt.ylabel(name)
    plt.legend()
    plt.show()

# %%
def plot2(DF, DF2, name1, name2 = 'Deaths', log = True):
    plt.figure(figsize = (14, 7))
    if log:
        plt.xscale('log')
        plt.yscale('log')
    for col in Important_countries:
        plt.plot(DF[col],
                 DF2[col],
                 label = col,
                 linestyle = '-.' if 'World' in col else '-',
                 color = colors[col] if col in colors else 'pink', 
                 #alpha = 0.6
                )
    plt.title(f'{name1} wrt {name2} in Countries')
    plt.xlabel(name2)
    plt.ylabel(name1)
    plt.legend()
    plt.show()

# %%
Deaths.tail(14)[Important_countries]
# Out:
#             India   World     US  Germany  Italy  Spain  China  \
# Date
# 2020-04-08    178   88338  14695     2349  17669  14792   3337
# 2020-04-09    226   95521  16544     2607  18279  15447   3339
# 2020-04-10    246  102525  18586     2767  18849  16081   3340
# 2020-04-11    288  108502  20462     2736  19468  16606   3343
# 2020-04-12    331  114090  22019     3022  19899  17209   3343
# 2020-04-13    358  119481  23528     3194  20465  17756   3345
# 2020-04-14    393  125983  25831     3294  21067  18056   3345
# 2020-04-15    405  134176  28325     3804  21645  18708   3346
# 2020-04-16    448  143800  32916     4052  22170  19315   3346
# 2020-04-17    486  153821  36773     4352  22745  20002   4636
# 2020-04-18    521  159509  38664     4459  23227  20043   4636
# 2020-04-19    559  165043  40661     4586  23660  20453   4636
# 2020-04-20    592  169985  42094     4862  24114  20852   4636
# 2020-04-21    645  176983  44845     5033  24648  21282   4636
Slope[Important_countries].tail(14)
# Out:
#              India   World      US  Germany   Italy   Spain   China  \
# Date
# 2020-04-08  0.9337  0.7533  0.9341   0.9053  0.3433  0.6776 -1.3846
# 2020-04-09  0.9078  0.7310  0.9238   0.8872  0.2659  0.6111 -1.4792
# 2020-04-10  0.9204  0.7107  0.9098   0.8619  0.1901  0.5426 -1.6364
# 2020-04-11  0.9167  0.6810  0.8930   0.8159  0.0914  0.4553 -1.4091
# 2020-04-12  0.9178  0.6571  0.8770   0.7903  0.0164  0.3740 -1.5897
# 2020-04-13  0.9080  0.6281  0.8592   0.7536 -0.0630  0.2655 -1.4595
# 2020-04-14  0.9106  0.5922  0.8285   0.7019 -0.1489  0.1732 -1.1944
# 2020-04-15  0.8415  0.5581  0.8032   0.6907 -0.1987  0.0598 -1.5000
# 2020-04-16  0.8191  0.5252  0.7878   0.6390 -0.2732 -0.0614 -2.0417
# 2020-04-17  0.8382  0.5003  0.7695   0.6074 -0.3206 -0.1535  0.9443
# 2020-04-18  0.8115  0.4559  0.7323   0.5489 -0.3397 -0.3058  0.9456
# 2020-04-19  0.8000  0.4280  0.7036   0.5037 -0.3394 -0.3913  0.9547
# 2020-04-20  0.7237  0.3915  0.6734   0.4472 -0.3761 -0.4685  0.9531
# 2020-04-21  0.7172  0.3339  0.6229   0.3838 -0.3704 -0.5527  0.9585
#
#             United Kingdom  France  Korea, South    Iran
# Date
# 2020-04-08          0.9311  0.8655        0.1081  0.1007
# 2020-04-09          0.9228  0.8433        0.1096  0.0378
# 2020-04-10          0.9083  0.8290       -0.0580 -0.0054
# 2020-04-11          0.8873  0.8070       -0.0746 -0.0359
# 2020-04-12          0.8712  0.7865       -0.2419 -0.0447
# 2020-04-13          0.8636  0.7590       -0.4068 -0.0416
# 2020-04-14          0.8319  0.7231       -0.3500 -0.0700
# 2020-04-15          0.7831  0.6661       -0.3500 -0.0919
# 2020-04-16          0.7426  0.5891       -0.3000 -0.0977
# 2020-04-17          0.6878  0.5018       -0.4286 -0.1184
# 2020-04-18          0.6345  0.4044       -0.3636 -0.2008
# 2020-04-19          0.5820  0.3634       -0.4118 -0.2660
# 2020-04-20          0.5478  0.2905       -0.5000 -0.3109
# 2020-04-21          0.4871  0.1187       -0.6000 -0.3600

# %%
plotter(Slope[[c for c in Important_countries if c!= 'China']].tail(50), 'Slope', False)

# %%
Biweekly_Growth = np.round(Biweekly_Deaths/Biweekly_Deaths.shift(14), 4)
Biweekly_Growth[Important_countries].tail(14)
# Out:
#               India   World       US  Germany   Italy   Spain    China  \
# Date
# 2020-04-08  15.0909  4.0539  15.1799  10.5567  1.5228  3.1019   0.4194
# 2020-04-09  10.8421  3.7169  13.1180   8.8636  1.3622  2.5712   0.4034
# 2020-04-10  12.5556  3.4563  11.0854   7.2388  1.2347  2.1864   0.3793
# 2020-04-11  12.0000  3.1349   9.3489   5.4316  1.1006  1.8358   0.4151
# 2020-04-12  12.1600  2.9167   8.1331   4.7682  1.0167  1.5975   0.3861
# 2020-04-13  10.8667  2.6891   7.1034   4.0589  0.9407  1.3615   0.4066
