# %% [markdown]
# ### Importing and building the plotting functions

# %%
import pandas as pd
import matplotlib.pyplot as plt
import datetime as dt
import numpy as np

# %%
# %matplotlib inline
pd.set_option('display.max_rows', 200)
pd.set_option('display.max_columns', 20)
plt.style.use('fivethirtyeight')
# plt.style.use('seaborn')

# %%
def plotter(DF, name, xlabel= 'Date', scale = 'log', col = 'imp'):
    plt.figure(figsize = (14, 7))
    plt.yscale(scale)
    
    columns = DF.columns if col == 'all' else Countries[::-1]
    for col in columns:
        plt.plot(DF.index,
                 DF[col],
                 label = col if col in Countries else None,
                 linestyle = ':' if 'World' in col else '-',
                 color = colors[col] if col in colors else 'pink', 
#                  alpha = 0.8 if col in Countries else 0.4
                )
    plt.title(name+' wrt Date in Countries')
    plt.xlabel(xlabel)
    plt.ylabel(name)
    plt.legend(loc = 2)
    plt.show()

# %%
def plotwrtDeaths(DF2, name1, DF, name2 = 'Deaths', scale = 'log', col = 'imp'):
    plt.figure(figsize = (14, 7))
    plt.xscale(scale)
    plt.yscale(scale)
    
#     plt.ylim(bottom=0.05, top=2*10**4)
    
    columns = DF.columns if col == 'all' else Countries[::-1]
    for col in columns:
        plt.plot(DF[col],
                 DF2[col],
                 label = col if col in Countries else None,
                 linestyle = ':' if 'World' in col else '-',
                 color = colors[col] if col in colors else 'pink', 
                 alpha = 0.8 if col in Countries else 0.4
                )
    plt.title(f'{name1} wrt {name2} in Countries')
    plt.xlabel(name2)
    plt.ylabel(name1)
    plt.legend(loc = 2)
    plt.show()

# %%
def stackplotter(DF, name, tail=None):
    plt.figure(figsize = (14, 7))
    
    if tail:
        DF = DF.tail(tail)
    columns = Countries[::-1]
    columns = [t for t in columns if 'World' not in t][::-1]
    
    plt.stackplot(DF.index, 
                  DF[['World']].T, 
                  labels=['World'], 
                  colors=['blue'], 
                  alpha=0.2,                 
                 )
    
    plt.stackplot(DF.index, 
                  DF[columns].T, 
                  labels=columns, 
                  colors=[colors[c] for c in columns], 
                  alpha=0.8,                 
                 )
    
    
    plt.title(name+' wrt Date in Countries')
    plt.xlabel('Date')
    plt.ylabel(name)
    plt.legend(loc = 2)
    plt.show()

# %% [markdown]
# ### Importing the Data from Johns Hopkins data

# %%
data_url = 'https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_deaths_global.csv'
DF = pd.read_csv(data_url)

# %%
DF = DF.groupby('Country/Region').sum()
DF = DF.drop(columns = ['Lat', 'Long']).transpose()
DF['World'] = DF.sum(axis = 1)
DF = DF.rename(columns = {'United Kingdom': 'UK', 'Korea, South': 'S.Korea', 'Country/Region': 'Date'})
DF.index = pd.to_datetime(DF.index, format = '%m/%d/%y')
# DF.index.rename('Date', inplace = True)

# %%
colors = {'India': 'Blue', 
          'World': 'Blue', 
          'US': 'Black', 
          'China': 'red', 
          'Spain': 'yellow',
          'Italy': 'grey', 
          'Iran': 'brown', 
          'UK': 'Purple', 
#           'S.Korea': 'lightgreen', 
          'France': 'violet', 
          'Poland': 'lime', 
          'Argentina': 'Teal',
          'Russia': 'cyan', 
          'Mexico': 'Orange', 
          'Brazil': 'darkgreen', 
#           'Belgium': 'cyan',
#           'New Zealand': 'lightblue'
         }

Countries = list(colors.keys())

# %%
Deaths = DF.copy()
Deaths[Countries].tail(5)
# Out:
# Country/Region   India    World      US  China  Spain  Italy   Iran     UK  \
# 2020-12-01      138122  1481306  270642   4743  45511  56361  48628  59148
# 2020-12-02      138648  1493742  273446   4744  45784  57045  48990  59796
# 2020-12-03      139188  1506260  276325   4745  46038  58038  49348  60210
# 2020-12-04      139700  1518670  278932   4746  46252  58852  49695  60714
# 2020-12-05      140182  1528868  281186   4746  46252  59514  50016  61111
#
# Country/Region  France  Poland  Argentina  Russia  Mexico  Brazil
# 2020-12-01       53595   17599      38928   40050  106765  173817
# 2020-12-02       53906   18208      39156   40630  107565  174515
# 2020-12-03       54231   18828      39305   41173  108173  175270
# 2020-12-04       54859   19359      39512   41730  108863  175964
# 2020-12-05       55073   19861      39632   42228  109456  176628

# %%
plotter(Deaths, 'Deaths')

# %%
Daily_Deaths = np.round((Deaths - Deaths.shift(1))/1)
Daily_Deaths = Daily_Deaths.fillna(0).astype('int')
Daily_Deaths[Countries].tail(5)
# Out:
# Country/Region  India  World    US  China  Spain  Italy  Iran   UK  France  \
# 2020-12-01        501  12848  2597      0    442    785   382  603     776
# 2020-12-02        526  12436  2804      1    273    684   362  648     311
# 2020-12-03        540  12518  2879      1    254    993   358  414     325
# 2020-12-04        512  12410  2607      1    214    814   347  504     628
# 2020-12-05        482  10198  2254      0      0    662   321  397     214
#
# Country/Region  Poland  Argentina  Russia  Mexico  Brazil
# 2020-12-01         449        198     559     825     697
# 2020-12-02         609        228     580     800     698
# 2020-12-03         620        149     543     608     755
# 2020-12-04         531        207     557     690     694
# 2020-12-05         502        120     498     593     664

# %%
EWM = np.round(Daily_Deaths.ewm(com=7).mean(), 2)
name = 'Exponential Weighted Mean Weekly'

Weekly_Avg = np.round((Deaths - Deaths.shift(7))/7, 2)
# name = 'Weekly Average Deaths'

AVG = EWM 
# AVG = Weekly_Avg
AVG[Countries].tail(5)
# Out:
# Country/Region   India     World       US  China   Spain   Italy    Iran  \
# 2020-12-01      498.04   9890.17  1479.62   0.10  280.83  676.53  425.54
# 2020-12-02      501.53  10208.40  1645.17   0.21  279.85  677.46  417.60
# 2020-12-03      506.34  10497.10  1799.40   0.31  276.62  716.91  410.15
# 2020-12-04      507.05  10736.21  1900.35   0.40  268.79  729.04  402.25
# 2020-12-05      503.92  10668.94  1944.55   0.35  235.19  720.66  392.10
#
# Country/Region      UK  France  Poland  Argentina  Russia  Mexico  Brazil
# 2020-12-01      428.24  522.02  423.16     217.21  449.50  535.18  493.72
# 2020-12-02      455.71  495.64  446.39     218.56  465.81  568.28  519.26
# 2020-12-03      450.50  474.31  468.09     209.86  475.46  573.25  548.72
# 2020-12-04      457.19  493.52  475.96     209.50  485.65  587.84  566.88
# 2020-12-05      449.66  458.58  479.21     198.32  487.20  588.49  579.02

# %%
plotter(np.round(AVG), name)

# %%
plotwrtDeaths(np.round(AVG, 1), name, Deaths)

# %%
stackplotter(AVG, name)

# %%
stackplotter(AVG.divide(AVG.World, axis=0), 'Deaths Percentage')

# %% [markdown]
# ### Reproductivity

# %%
Reproductivity = np.round(EWM/EWM.shift(14), 4).clip(lower= 0.1)
Reproductivity[EWM.shift(14) < 12] = 1
Reproductivity[Countries].iloc[-1]
# plt.barh(
#     Countries,
#     Reproductivity[Countries].iloc[-1],
#     color = colors.values()
# )
# Out:
# Country/Region
# India        0.9547
# World        1.1395
# US           1.4271
# China        1.0000
# Spain        0.8900
# Italy        1.2487
# Iran         0.8650
# UK           1.1032
# France       0.7993
# Poland       1.1104
# Argentina    0.7861
# Russia       1.2293
# Mexico       1.2030
# Brazil       1.1701
# Name: 2020-12-05 00:00:00, dtype: float64

# %%
plotter(Reproductivity.tail(100), 'RF')

# %% [markdown]
# ### Time Adjusted for starting day

# %%
def adjust_days(DF):
    X = DF.copy()
#     X.reset_index()
    for col in DF.columns:
        L = list(DF[Deaths[col]>5][col])
        X[col] = L + [None for _ in range(len(X[col]) - len(L))]
    return X.reset_index()[DF.columns]
xlabel= 'Days from 5 Deaths'

# %%
RF_A = adjust_days(Reproductivity)
plotter(RF_A.tail(100), 'Reproductivity', xlabel)

# %%
AVG_A = adjust_days(AVG)
plotter(np.round(AVG_A), 'Average Deaths', xlabel)

# %%
Deaths_A = adjust_days(Deaths)
plotter(Deaths_A, 'Deaths', xlabel)

# %% [markdown]
# ### Today's Statistics by combining the previous tables

# %%
LastDay_DF = pd.DataFrame()
LastDay_DF['Country'] = Deaths.columns
LastDay_DF = LastDay_DF.set_index('Country')

D = {
    'Deaths':Deaths,
    'Daily_Deaths':Daily_Deaths,
    'Weekly_Deaths': Weekly_Avg,
    'EWM7': EWM,
    'Reproductivity':Reproductivity,
    }
for name in D:
    LastDay_DF[name] = D[name].iloc[-1]

# %%
LastDay_DF.sort_values('Deaths', ascending = False).head(10)
# Out:
#           Deaths  Daily_Deaths  Weekly_Deaths      EWM7  Reproductivity
# Country
# World    1528868         10198       10859.43  10668.94          1.1395
# US        281186          2254        2162.71   1944.55          1.4271
# Brazil    176628           664         581.00    579.02          1.1701
# India     140182           482         498.00    503.92          0.9547
# Mexico    109456           593         571.00    588.49          1.2030
# UK         61111           397         426.29    449.66          1.1032
# Italy      59514           662         735.86    720.66          1.2487
# France     55073           214         408.71    458.58          0.7993
# Iran       50016           321         361.43    392.10          0.8650
# Spain      46252             0         226.29    235.19          0.8900

# %%
LastDay_DF[LastDay_DF['Weekly_Deaths']>300].sort_values('Weekly_Deaths', ascending = False)
# Out:
#           Deaths  Daily_Deaths  Weekly_Deaths      EWM7  Reproductivity
# Country
# World    1528868         10198       10859.43  10668.94          1.1395
# US        281186          2254        2162.71   1944.55          1.4271
# Italy      59514           662         735.86    720.66          1.2487
# Brazil    176628           664         581.00    579.02          1.1701
# Mexico    109456           593         571.00    588.49          1.2030
# Russia     42228           498         507.43    487.20          1.2293
# India     140182           482         498.00    503.92          0.9547
# Poland     19861           502         445.00    479.21          1.1104
# UK         61111           397         426.29    449.66          1.1032
# France     55073           214         408.71    458.58          0.7993
# Germany    18839           262         379.71    337.69          1.7609
# Iran       50016           321         361.43    392.10          0.8650

# %% [markdown]
# ### Pie Chart

# %%
def piechart(name='Deaths', size=12, DF=LastDay_DF):
    plt.figure(figsize = (size, size))
    DF = DF.sort_values(name, ascending = False)
    
    countries = DF.index[1:]
    deaths = DF[name][1:]
    
    print ('World total: ',int( DF.loc['World'][name]))
    
    plt.pie(deaths, 
            labels= [c +' '+ str(d) for c, d in zip(countries, deaths)], 
            startangle=90,
            counterclock=False,
            autopct='%1.f%%', 
#             pctdistance=0.8
           )
    
    plt.title(name+' piechart for every country')

# %%
piechart('Weekly_Deaths')
# Out:
# World total:  10859

# %%
piechart('Daily_Deaths')
# Out:
# World total:  10198

# %%
print('Today\'s Date: ', dt.datetime.now().date())
# Out:
# Today's Date:  2020-12-07

# %%
# Total estimated Cases: 
LastDay_DF.loc['World'].Deaths/0.002
# Out:
# 764434000.0

# %% [markdown]
# <p>Per Capita deaths are included in this  <a href="https://www.statista.com/statistics/1104709/coronavirus-deaths-worldwide-per-million-inhabitants/" rel="nofollow">Statista</a></p>
