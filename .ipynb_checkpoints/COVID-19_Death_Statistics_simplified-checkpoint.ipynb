# %%
import pandas as pd
import matplotlib.pyplot as plt
import datetime as dt
import numpy as np

# %%
# %matplotlib inline
pd.set_option('display.max_rows', 200)
pd.set_option('display.max_columns', 20)
plt.style.use('fivethirtyeight')

# %%
data_url = 'https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_deaths_global.csv'
DF = pd.read_csv(data_url)

# %%
DF = DF.groupby('Country/Region').sum()
DF = DF.drop(columns = ['Lat', 'Long']).transpose()
DF['World'] = DF.sum(axis = 1)
DF = DF.rename(columns = {'United Kingdom': 'UK', 'Korea, South': 'S.Korea', 'Country/Region': 'Date'})
DF.index = pd.to_datetime(DF.index, format = '%m/%d/%y')
DF['World without China'] = DF.World - DF.China
#DF.index.rename('Date', inplace = True)

# %%
Countries = ['India', 'World', 'World without China',
                      'US', 'Germany', 'Italy', 'Spain', 'China',
                      'UK', 'France', 'Brazil',
                      'S.Korea', 'Iran', 'Belgium', 'New Zealand', 
                       'Russia', 'Mexico', 'Canada']#[::-1]
Other_Countries = ['Belgium', 'Brazil', 'Canada', 'China', 'Ecuador', 'France', 'Germany',
       'India', 'Iran', 'Ireland', 'Italy', 'Mexico', 'Netherlands', 'Peru',
       'Portugal', 'Russia', 'Spain', 'Sweden', 'Switzerland', 'Turkey', 'US',
       'UK', 'World', 'S.Korea']
colors = {'India': 'Blue', 'World': 'Blue', 'World without China': 'Green', 'US': 'Black', 'China': 'red', 
          'Spain': 'yellow','Italy': 'grey', 'Iran': 'brown', 'Ireland': 'violet', 'UK': 'Purple', 
          'S.Korea': 'Black', 'France': 'orange', 'Germany': 'lime', 'Australia': 'Teal',
          'Russia': 'Brown', 'Mexico': 'Orange', 'Canada': 'Teal', 'Brazil': 'darkgreen', 'Belgium': 'cyan',
          'New Zealand': 'cyan'}

# %%
def plotter(DF, name, scale = 'log', col = 'imp'):
    plt.figure(figsize = (14, 7))
    plt.yscale(scale)
    
    columns = DF.columns if col == 'all' else Countries[::-1]
    for col in columns:
        plt.plot(DF.index,
                 DF[col],
                 label = col if col in Countries else None,
                 linestyle = '-.' if 'World' in col else '-',
                 color = colors[col] if col in colors else 'pink', 
                 alpha = 0.8 if col in Countries else 0.4
                )
    plt.title(name+' wrt Date in Countries')
    plt.xlabel('Date')
    plt.ylabel(name)
    plt.legend(loc = 2)
    plt.show()

# %%
def plotwrtDeaths(DF2, name1, DF, name2 = 'Deaths', scale = 'log', col = 'imp'):
    plt.figure(figsize = (14, 7))
    plt.xscale(scale)
    plt.yscale(scale)
    
    columns = DF.columns if col == 'all' else Countries[::-1]
    for col in columns:
        plt.plot(DF[col],
                 DF2[col],
                 label = col if col in Countries else None,
                 linestyle = '-.' if 'World' in col else '-',
                 color = colors[col] if col in colors else 'pink', 
                 alpha = 0.8 if col in Countries else 0.4
                )
    plt.title(f'{name1} wrt {name2} in Countries')
    plt.xlabel(name2)
    plt.ylabel(name1)
    plt.legend(loc = 2)
    plt.show()

# %%
Deaths = DF.copy()

# %%
Deaths[Countries].tail(14)
# Out:
# Country/Region  India   World  World without China      US  Germany  Italy  \
# 2020-05-19       3302  323285               318647   91921     8081  32169
# 2020-05-20       3434  328115               323477   93439     8144  32330
# 2020-05-28          2      0  377      66    1156        0    63       24
# 2020-05-29          2      0  324      52    1124        0    50       42
# 2020-05-30          4      0  215      57     956        1    57       23
# 2020-05-31          2      0  113      31     480        1    63       14
# 2020-06-01          0      0  556      31     623        1    81       19
#
# Country/Region  New Zealand  Russia  Mexico  Canada
# 2020-05-19                0     115     334      68
# 2020-05-20                0     135     424     122
# 2020-05-21                0     127     420     117
# 2020-05-22                0     150     479      93
# 2020-05-23                0     139     190     106
# 2020-05-24                0     153     215      68
# 2020-05-25                0      92     239     121
# 2020-05-26                0     174     501      98
# 2020-05-27                1     161     463     123
# 2020-05-28                0     174     447     106
# 2020-05-29                0     232     371      81
# 2020-05-30                0     181     364      96
# 2020-05-31                0     138     151     215
# 2020-06-01                0     156     237      30

# %%
plotter(Daily_Deaths.tail(14), '7 Days Avg Deaths', scale = 'log')

# %%
Reproductivity = np.round(Weekly_Deaths/Biweekly_Deaths.shift(8), 4)#.iloc[-1]
Reproductivity[Countries].iloc[-1]
# Out:
# Country/Region
# India                  1.5839
# World                  0.9408
# World without China    0.9408
# US                     0.7634
# Germany                0.6863
# Italy                  0.5348
# Spain                  0.2759
# China                  0.0000
# UK                     0.8607
# France                 0.3805
# Brazil                 1.1195
# S.Korea                0.0000
# Iran                   1.0991
# Belgium                0.5609
# New Zealand               NaN
# Russia                 1.4982
# Mexico                 1.2899
# Canada                 0.9709
# Name: 2020-06-01 00:00:00, dtype: float64

# %%
plotter(Reproductivity, 'RF')
pd.melt(Reproductivity).to_csv('CSVs/Reproductivity.csv')

# %%
plotwrtDeaths(Reproductivity, 'RF', Deaths)

# %%
LastDay_DF = pd.DataFrame()
LastDay_DF['Country'] = Deaths.columns
LastDay_DF = LastDay_DF.set_index('Country')

# %%
D = {
    'Deaths':Deaths,
    'Biweekly Deaths':Biweekly_Deaths,
    'Weekly Deaths': Weekly_Deaths,
    'Triday Deaths': ThreeDaysDeaths,
    'Daily Deaths':Daily_Deaths,
    'Reproductive Factor':Reproductivity,
    }
for name in D:
    LastDay_DF[name] = D[name].iloc[-1]
All_lastday = LastDay_DF
LastDay_DF = LastDay_DF[LastDay_DF.Deaths>=4000]

# %%
LastDay_DF.sort_values('Deaths', ascending = False)#.head(20)
# Out:
#                      Deaths  Biweekly Deaths  Weekly Deaths  Triday Deaths  \
# Country
# World                375559          4077.00           4190           3520
# World without China  370921          4077.00           4190           3520
# US                   105165          1058.43            992            785
# UK                    39127           303.64            304            295
# Italy                 33475           104.86             85             82
# Brazil                29937           934.57            923            686
# France                28836            42.43             54             40
# Spain                 27127           -41.57             42              2
# Mexico                10167           345.36            362            251
# Belgium                9486            29.00             25             19
# Germany                8555            39.43             35             17
# Iran                   7878            58.64             61             67
# Canada                 7404           103.14            107            114
# Netherlands            5981            19.14             19             10
# India                  5608           175.14            205            209
# Russia                 4849           151.93            174            158
# China                  4638             0.00              0              0
# 2020-05-29     -0.0079    0.0  0.0066  0.0021  0.0350   0.0000  0.0070
# 2020-05-30     -0.0082    0.0  0.0063  0.0022  0.0338   0.0037  0.0070
# 2020-05-31     -0.0086    0.0  0.0063  0.0022  0.0324   0.0037  0.0069
# 2020-06-01      0.0015    0.0  0.0078  0.0019  0.0308   0.0000  0.0077
#
# Country/Region  Belgium  New Zealand  Russia  Mexico  Canada
# 2020-05-19       0.0055          0.0  0.0363  0.0439  0.0173
# 2020-05-20       0.0048          0.0  0.0367  0.0438  0.0169
# 2020-05-21       0.0044          0.0  0.0365  0.0445  0.0153
# 2020-05-22       0.0039          0.0  0.0366  0.0454  0.0153
# 2020-05-23       0.0036          0.0  0.0360  0.0425  0.0147
# 2020-05-24       0.0036          0.0  0.0367  0.0429  0.0138
# 2020-05-25       0.0035          0.0  0.0358  0.0431  0.0149
# 2020-05-26       0.0034          0.0  0.0365  0.0434  0.0154
# 2020-05-27       0.0033          0.0  0.0358  0.0416  0.0151
# 2020-05-28       0.0031          0.0  0.0360  0.0400  0.0146
# 2020-05-29       0.0033          0.0  0.0368  0.0369  0.0142
# 2020-05-30       0.0033          0.0  0.0367  0.0379  0.0138
# 2020-05-31       0.0029          0.0  0.0352  0.0365  0.0163
# 2020-06-01       0.0026          0.0  0.0359  0.0356  0.0145

# %%
def days100(DF):
    X = DF.copy()
#     X.reset_index()
    for col in DF.columns:
        L = list(DF[Deaths[col]>5][col])
        X[col] = L + [None for _ in range(len(X[col]) - len(L))]
    return X.reset_index()[DF.columns]

# %%
RF = days100(Reproductivity)
plotter(RF[[cun for cun in Countries if cun not in ['China', 'World']]], 'Reproductivity', col = 'all')

# %%
LastDay_DF.index
# Out:
# Index(['Belgium', 'Brazil', 'Canada', 'China', 'France', 'Germany', 'India',
#        'Iran', 'Italy', 'Mexico', 'Netherlands', 'Peru', 'Russia', 'Spain',
#        'Sweden', 'Turkey', 'US', 'UK', 'World', 'World without China'],
#       dtype='object', name='Country')

# %%
BD = days100(Biweekly_Deaths)
plotter(BD[[cun for cun in Countries if cun not in ['China', 'World']]], 'Biweekly_TA', col = 'all')

# %%
D = days100(Deaths)
plotter(D[[cun for cun in Countries if cun not in ['China', 'World']]], 'Deaths_TA', col = 'all')

# %%
def TA(DF):
    X = DF.copy()
#     X.reset_index()
    for col in DF.columns:
        L = list(DF[Deaths[col]>5][col])
        X[col] = L + [0 for _ in range(len(X[col]) - len(L))]
    return X

# %%
def csvify(X, name):
    DF = X.copy()
    DF['Date'] = DF.index
    DF = pd.melt(DF, id_vars = 'Date')
    DF.to_csv(f'CSVs\\{name}.csv', index = False)

# %%
for name, df in {'Deaths': Deaths, 
           'BiweeklyDeaths': Biweekly_Deaths,
           'Daily_Deaths': Daily_Deaths,
           'Reproductivity': Reproductivity,
          }.items():
    csvify(df, name)
    csvify(TA(df), 'TA_' + name)

# %%
plotwrtDeaths(Reproductivity, 'RF wrt Deaths', Deaths)
